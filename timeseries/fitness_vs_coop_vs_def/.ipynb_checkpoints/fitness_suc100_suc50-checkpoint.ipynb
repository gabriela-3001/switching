# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter
from matplotlib.colors import ListedColormap, BoundaryNorm, Normalize

# %%
examples = [8101]

all_50 = {}

for ex in examples:
    
    print(ex)

    df = pd.read_csv('fitness/detailed/suc_50/' + str(ex), sep = '\s+', header = None)
    columns = ['time', 'sucrose', 'glucose', 'cooperator', 'switch', 'defector']
    df.columns = columns
    
    all_50[ex] = df
    
    
all_100 = {}

for ex in examples:
    
    print(ex)

    df = pd.read_csv('fitness/detailed/suc_100/' + str(ex), sep = '\s+', header = None)
    columns = ['time', 'sucrose', 'glucose', 'cooperator', 'switch', 'defector']
    df.columns = columns
    
    all_100[ex] = df
# Out:
# 8101
# 8101

# %%
fig, ax = plt.subplots(2,2, figsize = (16,12))

ax[0,0].set_ylabel('Frequencies', fontsize = 16)  # Set the label for the y-axis
ax[0,0].plot(all_100[8101]['time'], all_100[8101]['cooperator'] / all_100[8101][['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,0].plot(all_100[8101]['time'], all_100[8101]['switch'] / all_100[8101][['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,0].plot(all_100[8101]['time'], all_100[8101]['defector'] / all_100[8101][['cooperator', 'switch', 'defector']].sum(axis = 1), color='red', linewidth = 3)

ax[0,1].plot(all_50[8101]['time'], all_50[8101]['cooperator'] / all_50[8101][['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,1].plot(all_50[8101]['time'], all_50[8101]['switch'] / all_50[8101][['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,1].plot(all_50[8101]['time'], all_50[8101]['defector'] / all_50[8101][['cooperator', 'switch', 'defector']].sum(axis = 1), color='red', linewidth = 3)

ax[0,0].plot(all_100[8101]['time'],all_100[8101]['sucrose'], color='k', linewidth = 2)
ax[0,0].plot(all_100[8101]['time'],all_100[8101]['glucose'], color='silver', linewidth = 2)
ax[0,0].set_ylabel('Frequencies, Sugar levels', fontsize = 16)  # Set the label for the y-axis

ax[0,1].plot(all_50[8101]['time'],all_50[8101]['sucrose'], color='k', linewidth = 2)
ax[0,1].plot(all_50[8101]['time'],all_50[8101]['glucose'], color='silver', linewidth = 2)
#ax[0,1].set_ylabel('Frequencies, Sugar levels', fontsize = 16)  # Set the label for the y-axis

ax[1,0].plot(all_100[8101]['time'],all_100[8101]['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,0].plot(all_100[8101]['time'],all_100[8101]['switch'], color = 'gold', linewidth = 3)
ax[1,0].plot(all_100[8101]['time'],all_100[8101]['defector'], color = 'firebrick', linewidth = 3)

ax[1,1].plot(all_50[8101]['time'],all_50[8101]['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,1].plot(all_50[8101]['time'],all_50[8101]['switch'], color = 'gold', linewidth = 3)
ax[1,1].plot(all_50[8101]['time'],all_50[8101]['defector'], color = 'firebrick', linewidth = 3)

ax[1,0].set_ylabel('Abundances', fontsize = 16)

ax[0,0].set_title('Sucrose 100%', fontsize = 30)
ax[0,1].set_title('Sucrose 50%', fontsize = 30)

for i in range(2):
    ax[1,i].set_xlabel('Time', fontsize = 16)
    ax[1,i].set_ylim(-0.05,2.5)
    for j in range(2):
        ax[i,j].tick_params(labelsize = 15)
        ax[i,j].set_xlim(1000,2000)
        ax[0,j].set_ylim(-0.05,1.05)

plt.tight_layout()
plt.savefig('timeseries_8101_suc100_suc50_JUL13.png', dpi = 500, bbox_inches = 'tight')

# %%
plt.plot(all_90[2031]['time'], all_90[2031]['cooperator'], color='dodgerblue', linewidth = 3)
plt.plot(all_90[2031]['time'], all_90[2031]['switch'], color='gold', linewidth = 3)
plt.xlim(1150,1250)
# Out:
# (1150, 1250)

# %%
plt.plot(all_90[2031]['time'],all_90[2031]['sucrose'], color='k', linewidth = 2)
plt.plot(all_90[2031]['time'],all_90[2031]['glucose'], color='grey', linewidth = 2)
plt.plot(all_90[2031]['time'], all_90[2031]['cooperator'] / all_90[2031][['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
plt.plot(all_90[2031]['time'], all_90[2031]['switch'] / all_90[2031][['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
plt.plot(all_90[2031]['time'], all_90[2031]['defector'] / all_90[2031][['cooperator', 'switch', 'defector']].sum(axis = 1), color='red', linewidth = 3)

plt.legend(['Sucrose', 'Glucose', 'Cooperator', 'Fitness switch', "Defector"], fontsize = 14, loc = 'upper right', bbox_to_anchor = (2,1.2), ncol=5)
plt.savefig('timeseries_2031_112_90_legend_JUL2.png', dpi = 500, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(2,2, figsize = (16,12))

ax[0,0].set_ylabel('Frequencies', fontsize = 16)  # Set the label for the y-axis
ax[0,0].plot(df_sucrose_100['time'], df_sucrose_100['cooperator'] / df_sucrose_100[['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,0].plot(df_sucrose_100['time'], df_sucrose_100['switch'] / df_sucrose_100[['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,0].plot(df_sucrose_100['time'], df_sucrose_100['defector'] / df_sucrose_100[['cooperator', 'switch', 'defector']].sum(axis = 1), color='firebrick', linewidth = 3)

ax[0,1].plot(df_sucrose_10['time'], df_sucrose_10['cooperator'] / df_sucrose_10[['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,1].plot(df_sucrose_10['time'], df_sucrose_10['switch'] / df_sucrose_10[['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,1].plot(df_sucrose_10['time'], df_sucrose_10['defector'] / df_sucrose_10[['cooperator', 'switch', 'defector']].sum(axis = 1), color='firebrick', linewidth = 3)

ax[0,0].legend(['Cooperator', 'Switch', 'Defector'], loc = 'center right', fontsize = 13)

ax2 = ax[0,0].twinx()
ax2.plot(df_sucrose_100['time'],df_sucrose_100['sucrose'], color='green')
ax2.plot(df_sucrose_100['time'],df_sucrose_100['glucose'], color='darkorange')
ax2.legend(['Sucrose', 'Glucose'], loc = (0.7,0.6), fontsize = 16)
ax2.set_ylabel('Sugar levels', fontsize = 16)  # Set the label for the y-axis



ax3 = ax[0,1].twinx()
ax3.plot(df_sucrose_10['time'],df_sucrose_10['sucrose'], color='green')
ax3.plot(df_sucrose_10['time'],df_sucrose_10['glucose'], color='darkorange')

ax[0,1].set_ylabel('Frequencies', fontsize = 16)
ax3.set_ylabel('Sugars', fontsize = 16)

ax2.set_ylim(0,3)
ax3.set_ylim(0,3)

ax[1,0].plot(df_sucrose_100['time'],df_sucrose_100['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,0].plot(df_sucrose_100['time'],df_sucrose_100['switch'], color = 'gold', linewidth = 3)
ax[1,0].plot(df_sucrose_100['time'],df_sucrose_100['defector'], color = 'firebrick', linewidth = 3)

ax[1,1].plot(df_sucrose_10['time'],df_sucrose_10['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,1].plot(df_sucrose_10['time'],df_sucrose_10['switch'], color = 'gold', linewidth = 3)
ax[1,1].plot(df_sucrose_10['time'],df_sucrose_10['defector'], color = 'firebrick', linewidth = 3)

ax[1,0].set_ylabel('Abundances', fontsize = 16)

ax2.tick_params(labelsize = 15)
ax3.tick_params(labelsize = 15)

for i in range(2):
    ax[1,i].set_xlabel('Time', fontsize = 16)
    ax[0,i].set_ylim(0,1)
    for j in range(2):
        ax[i,j].tick_params(labelsize = 15)
        ax[i,j].set_xlim(500,1500)

plt.tight_layout()
plt.savefig('timeseries_def_100_10_JUN28.png', dpi = 500, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(2,2, figsize = (16,12))

ax[0,0].set_ylabel('Frequencies', fontsize = 16)  # Set the label for the y-axis
ax[0,0].plot(all_90[2031]['time'], all_90[2031]['cooperator'] / all_90[2031][['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,0].plot(all_90[2031]['time'], all_90[2031]['switch'] / all_90[2031][['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,0].plot(all_90[2031]['time'], all_90[2031]['defector'] / all_90[2031][['cooperator', 'switch', 'defector']].sum(axis = 1), color='firebrick', linewidth = 3)

ax[0,1].plot(all_90[112]['time'], all_90[112]['cooperator'] / all_90[112][['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,1].plot(all_90[112]['time'], all_90[112]['switch'] / all_90[112][['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,1].plot(all_90[112]['time'], all_90[112]['defector'] / all_90[112][['cooperator', 'switch', 'defector']].sum(axis = 1), color='firebrick', linewidth = 3)

ax[0,0].legend(['Cooperator', 'Switch'], loc = 'upper right', fontsize = 16)

#ax2 = ax[0,0].twinx()
#ax2.plot(all_90[2031]['time'],all_90[2031]['sucrose'], color='green')
#ax2.plot(all_90[2031]['time'],all_90[2031]['glucose'], color='darkorange')
#ax2.legend(['Sucrose', 'Glucose'], loc = 'upper left', fontsize = 16)
#ax2.set_ylabel('Sugar levels', fontsize = 16)  # Set the label for the y-axis



#ax3 = ax[0,1].twinx()
#ax3.plot(all_90[112]['time'],all_90[112]['sucrose'], color='green')
#ax3.plot(all_90[112]['time'],all_90[112]['glucose'], color='darkorange')

ax[0,1].set_ylabel('Frequencies', fontsize = 16)
#ax3.set_ylabel('Sugars', fontsize = 16)

#ax2.set_ylim(0,1.5)
#ax3.set_ylim(0,1.5)

ax[1,0].plot(all_90[2031]['time'],all_90[2031]['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,0].plot(all_90[2031]['time'],all_90[2031]['switch'], color = 'gold', linewidth = 3)
ax[1,0].plot(all_90[2031]['time'],all_90[2031]['defector'], color = 'firebrick', linewidth = 3)

ax[1,1].plot(all_90[112]['time'],all_90[112]['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,1].plot(all_90[112]['time'],all_90[112]['switch'], color = 'gold', linewidth = 3)
ax[1,1].plot(all_90[112]['time'],all_90[112]['defector'], color = 'firebrick', linewidth = 3)

ax[1,0].set_ylabel('Abundances', fontsize = 16)

#ax2.tick_params(labelsize = 15)
#ax3.tick_params(labelsize = 15)

for i in range(2):
    ax[1,i].set_xlabel('Time', fontsize = 16)
    for j in range(2):
        ax[i,j].tick_params(labelsize = 15)
        #ax[i,j].set_xlim(1000,2000)

plt.tight_layout()
plt.savefig('timeseries_2031_112_09_zoomout_JUN27.png', dpi = 500, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(2,2, figsize = (16,12))

ax[0,0].set_ylabel('Frequencies', fontsize = 16)  # Set the label for the y-axis
ax[0,0].plot(df_sucrose_100['time'], df_sucrose_100['cooperator'] / df_sucrose_100[['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,0].plot(df_sucrose_100['time'], df_sucrose_100['switch'] / df_sucrose_100[['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,0].plot(df_sucrose_100['time'], df_sucrose_100['defector'] / df_sucrose_100[['cooperator', 'switch', 'defector']].sum(axis = 1), color='firebrick', linewidth = 3)

ax[0,1].plot(df_sucrose_10['time'], df_sucrose_10['cooperator'] / df_sucrose_10[['cooperator', 'switch', 'defector']].sum(axis = 1), color='dodgerblue', linewidth = 3)
ax[0,1].plot(df_sucrose_10['time'], df_sucrose_10['switch'] / df_sucrose_10[['cooperator', 'switch', 'defector']].sum(axis = 1), color='gold', linewidth = 3)
ax[0,1].plot(df_sucrose_10['time'], df_sucrose_10['defector'] / df_sucrose_10[['cooperator', 'switch', 'defector']].sum(axis = 1), color='firebrick', linewidth = 3)

ax[0,0].legend(['Cooperator', 'Switch'], loc = 'center right', fontsize = 16)

ax[0,1].set_ylabel('Frequencies', fontsize = 16)


ax[1,0].plot(df_sucrose_100['time'],df_sucrose_100['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,0].plot(df_sucrose_100['time'],df_sucrose_100['switch'], color = 'gold', linewidth = 3)
ax[1,0].plot(df_sucrose_100['time'],df_sucrose_100['defector'], color = 'firebrick', linewidth = 3)

ax[1,1].plot(df_sucrose_10['time'],df_sucrose_10['cooperator'], color = 'dodgerblue', linewidth = 3)
ax[1,1].plot(df_sucrose_10['time'],df_sucrose_10['switch'], color = 'gold', linewidth = 3)
ax[1,1].plot(df_sucrose_10['time'],df_sucrose_10['defector'], color = 'firebrick', linewidth = 3)

ax[1,0].set_ylabel('Abundances', fontsize = 16)


for i in range(2):
    ax[1,i].set_xlabel('Time', fontsize = 16)
    for j in range(2):
        ax[i,j].tick_params(labelsize = 15)

plt.tight_layout()
plt.savefig('timeseries_def_100_10_zoomout_JUN27.png', dpi = 500, bbox_inches = 'tight')

# %%
plt.plot(df_5818['cooperator'])
plt.plot(df_6020['cooperator'])
plt.show()

# %%
plt.scatter(df_5818['sucrose'], df_5818['cooperator']-df_6020['cooperator'], s = 0.1)

# %%
fig, ax1 = plt.subplots()

# Plotting the first dataset on ax1
color = 'tab:red'
ax1.set_xlabel('X-axis label')  # Set the label for the x-axis
ax1.set_ylabel('Difference of cooperators', color=color)  # Set the label for the y-axis
ax1.plot(df_5818['cooperator'] - df_6020['cooperator'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Creating a second y-axis
ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Sucrose', color=color)  # Label for the second y-axis
ax2.plot(df_5818['sucrose'], color=color)
ax2.tick_params(axis='y', labelcolor=color)


ax1.set_xlim(200000,400000)

# Show the plot
plt.show()

# %%
fig, ax1 = plt.subplots()

# Plotting the first dataset on ax1
color = 'tab:red'
ax1.set_xlabel('X-axis label')  # Set the label for the x-axis
ax1.set_ylabel('Difference of cooperators', color=color)  # Set the label for the y-axis
ax1.plot(df_5818['cooperator'] / df_5818[['cooperator', 'switch', 'defector']].sum(axis = 1), color=color)
ax1.plot(df_5818['switch'] / df_5818[['cooperator', 'switch', 'defector']].sum(axis = 1), color='orange')
ax1.tick_params(axis='y', labelcolor=color)

# Creating a second y-axis
ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Glucose', color=color)  # Label for the second y-axis
ax2.plot(df_5818['glucose'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Show the plot
plt.show()

# %%
fig, ax1 = plt.subplots()

# Plotting the first dataset on ax1
color = 'tab:red'
ax1.set_xlabel('X-axis label')  # Set the label for the x-axis
ax1.set_ylabel('Difference of cooperators', color=color)  # Set the label for the y-axis
ax1.plot(df_6020['cooperator'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1), color=color)
ax1.plot(df_6020['switch'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1), color='orange')
ax1.tick_params(axis='y', labelcolor=color)

# Creating a second y-axis
ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Glucose', color=color)  # Label for the second y-axis
ax2.plot(df_5818['glucose'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax1.set_xlim(0.25e7,0.7e7)

# Show the plot
plt.show()

# %%
diff1 = df_6020['cooperator'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1)
diff2 = df_5818['cooperator'] / df_5818[['cooperator', 'switch', 'defector']].sum(axis = 1)

# %%
plt.plot(diff1-diff2, color=color)

# %%
fig, ax1 = plt.subplots()

# Plotting the first dataset on ax1
color = 'tab:red'
ax1.set_xlabel('X-axis label')  # Set the label for the x-axis
ax1.set_ylabel('Difference of cooperators', color=color)  # Set the label for the y-axis
ax1.plot(df_6020['cooperator'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1), color=color)
ax1.plot(df_6020['switch'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1), color='orange')
ax1.tick_params(axis='y', labelcolor=color)

# Creating a second y-axis
ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Sucrose', color=color)  # Label for the second y-axis
ax2.plot(df_5818['sucrose'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Show the plot
plt.show()

# %%
plt.scatter(df_8091['cooperator'], df_9111['cooperator'])

# %%
df_4182[['cooperator', 'switch', 'defector']].sum(axis = 1)
# Out:
# 0       0.000100
# 1       0.000720
# 2       0.007155
# 3       0.077467
# 4       1.202929
#           ...
# 996     0.113426
# 997     0.102632
# 998     0.092865
# 999     0.550694
# 1000    0.664117
# Length: 1001, dtype: float64

# %%
plt.plot(df_5818['cooperator'] / df_5818[['cooperator', 'switch', 'defector']].sum(axis = 1))
plt.plot(df_6020['cooperator'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1))

# %%
fig, ax = plt.subplots(3,2, figsize = (15,15))

ax[0,0].plot(df_5818['cooperator'] - df_6020['cooperator'], c ='k')
#ax[0,0].set_xlim(0,100)

ax[0,1].plot(df_5818['switch'] - df_6020['switch'], c ='k')
#ax[0,1].set_xlim(0,100)

ax[1,1].plot(df_5818['defector'])
ax[1,1].plot(df_6020['defector'])
#ax[1,1].set_xlim(0,100)

#ax[1,0].plot(df_5818['cooperator'] / df_5818[['cooperator', 'switch', 'defector']].sum(axis = 1))
#ax[1,0].plot(df_6020['cooperator'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1))

diff1 = df_5818['cooperator'] / df_5818[['cooperator', 'switch', 'defector']].sum(axis = 1)
diff2 = df_6020['cooperator'] / df_6020[['cooperator', 'switch', 'defector']].sum(axis = 1)

ax[1,0].plot(diff1 - diff2)

ax[0,1].set_xlim(0,100)

ax[1,0].set_xlim(0,100)

ax[0,0].set_title('cooperator')
ax[0,1].set_title('switch')
ax[1,1].set_title('defector')

ax[2,0].plot(df_5818['glucose'] - df_6020['glucose'], c ='k')
ax[2,1].plot(df_5818['sucrose'] - df_6020['sucrose'], c ='k')

ax[2,0].set_xlim(0,100)
ax[2,1].set_xlim(0,100)

plt.tight_layout()
#plt.savefig('timeseries_JUN25.png')

# %%
plt.plot(df_5818['switch'])
plt.plot(df_6020['switch'])
plt.xlim(400,500)
# Out:
# (400, 500)

# %%
plt.scatter(df_5818['cooperator'], df_6020['cooperator'], s = 5)

# %%
df_6020
# Out:
#           time       sucrose       glucose  cooperator    switch  defector
# 0          0.0  1.000000e+00  0.000000e+00    0.000033  0.000033  0.000033
# 1        100.0  1.561261e-01  6.480191e-02    0.431605  0.434010  0.000207
# 2        200.0  3.380330e-03  1.413200e-03    0.778765  0.764180  0.000279
# 3        300.0  3.000000e-08  1.000000e-08    0.472323  0.459905  0.000153
# 4        400.0  0.000000e+00  0.000000e+00    0.173758  0.169190  0.000056
# ...        ...           ...           ...         ...       ...       ...
# 996    99600.0  0.000000e+00  0.000000e+00    0.086274  0.080790  0.000000
# 997    99700.0  0.000000e+00  0.000000e+00    0.031738  0.029721  0.000000
# 998    99800.0  0.000000e+00  0.000000e+00    0.011676  0.010934  0.000000
# 999    99900.0  1.776700e-04  7.690000e-05    0.173186  0.164069  0.000000
# 1000  100000.0  2.139450e-03  9.281200e-04    0.445828  0.421481  0.000000
#
# [1001 rows x 6 columns]

# %%
df_6081
# Out:
#           time       sucrose       glucose  cooperator    switch  defector
# 0          0.0  1.000000e+00  0.000000e+00    0.000033  0.000033  0.000033
# 1        100.0  8.169380e-03  1.568831e-02    0.782327  0.739259  0.000072
# 2        200.0  8.000000e-08  1.900000e-07    1.337798  1.160027  0.000053
# 3        300.0  0.000000e+00  0.000000e+00    0.824956  0.685679  0.000025
# 4        400.0  0.000000e+00  0.000000e+00    0.303484  0.252247  0.000009
# ...        ...           ...           ...         ...       ...       ...
# 996    99600.0  0.000000e+00  0.000000e+00    0.268553  0.000000  0.000000
# 997    99700.0  0.000000e+00  0.000000e+00    0.098795  0.000000  0.000000
# 998    99800.0  0.000000e+00  0.000000e+00    0.036345  0.000000  0.000000
# 999    99900.0  0.000000e+00  0.000000e+00    0.512527  0.000000  0.000000
# 1000  100000.0  1.000000e-08  5.000000e-08    1.389026  0.000000  0.000000
#
# [1001 rows x 6 columns]

# %%
df_8091
# Out:
#           time   sucrose       glucose  cooperator    switch  defector
# 0          0.0  1.000000  0.000000e+00    0.000033  0.000033  0.000033
# 1        100.0  0.003798  4.228500e-03    0.878398  0.822784  0.000026
# 2        200.0  0.000000  1.000000e-08    1.532685  1.263386  0.000013
# 3        300.0  0.000000  0.000000e+00    0.954113  0.738515  0.000005
# 4        400.0  0.000000  0.000000e+00    0.350998  0.271684  0.000002
# ...        ...       ...           ...         ...       ...       ...
# 996    99600.0  0.000000  0.000000e+00    0.300781  0.000000  0.000000
# 997    99700.0  0.000000  0.000000e+00    0.110651  0.000000  0.000000
# 998    99800.0  0.000000  0.000000e+00    0.040706  0.000000  0.000000
# 999    99900.0  0.000000  0.000000e+00    0.566373  0.000000  0.000000
# 1000  100000.0  0.000000  0.000000e+00    1.553709  0.000000  0.000000
#
# [1001 rows x 6 columns]

# %%
df_2931
# Out:
#           time   sucrose  glucose  cooperator    switch  defector
# 0          0.0  1.000000  0.00000    0.000033  0.000033  0.000033
# 1        100.0  0.002233  0.00966    0.980238  0.954791  0.000286
# 2        200.0  0.000000  0.00000    1.612648  1.492050  0.000291
# 3        300.0  0.000000  0.00000    0.985210  0.888731  0.000151
# 4        400.0  0.000000  0.00000    0.362438  0.326946  0.000055
# ...        ...       ...      ...         ...       ...       ...
# 996    99600.0  0.000000  0.00000    0.332579  0.000000  0.000000
# 997    99700.0  0.000000  0.00000    0.122349  0.000000  0.000000
# 998    99800.0  0.000000  0.00000    0.045010  0.000000  0.000000
# 999    99900.0  0.000000  0.00000    0.642263  0.000000  0.000000
# 1000  100000.0  0.000000  0.00000    1.722581  0.000000  0.000000
#
# [1001 rows x 6 columns]

# %%
df_3980
# Out:
#           time   sucrose   glucose  cooperator    switch  defector
# 0          0.0  1.000000  0.000000    0.000033  0.000033  0.000033
# 1        100.0  0.081774  0.050469    0.642085  0.645036  0.000401
# 2        200.0  0.000284  0.000177    1.096548  1.071403  0.000555
# 3        300.0  0.000000  0.000000    0.663743  0.642859  0.000313
# 4        400.0  0.000000  0.000000    0.244177  0.236494  0.000115
# ...        ...       ...       ...         ...       ...       ...
# 996    99600.0  0.000000  0.000000    0.123133  0.109063  0.000000
# 997    99700.0  0.000000  0.000000    0.045298  0.040122  0.000000
# 998    99800.0  0.000000  0.000000    0.016664  0.014760  0.000000
# 999    99900.0  0.000003  0.000002    0.243474  0.218216  0.000000
# 1000  100000.0  0.000154  0.000105    0.636334  0.569881  0.000000
#
# [1001 rows x 6 columns]

# %%
df_4081
# Out:
#           time   sucrose   glucose  cooperator    switch  defector
# 0          0.0  1.000000  0.000000    0.000033  0.000033  0.000033
# 1        100.0  0.080714  0.049835    0.640512  0.637574  0.000380
# 2        200.0  0.000274  0.000171    1.098969  1.055755  0.000518
# 3        300.0  0.000000  0.000000    0.665980  0.632785  0.000291
# 4        400.0  0.000000  0.000000    0.245000  0.232788  0.000107
# ...        ...       ...       ...         ...       ...       ...
# 996    99600.0  0.000000  0.000000    0.125823  0.104259  0.000000
# 997    99700.0  0.000000  0.000000    0.046288  0.038355  0.000000
# 998    99800.0  0.000000  0.000000    0.017028  0.014110  0.000000
# 999    99900.0  0.000002  0.000001    0.248361  0.208443  0.000000
# 1000  100000.0  0.000128  0.000091    0.649982  0.545195  0.000000
#
# [1001 rows x 6 columns]
